# %%
# !wget https://web.archive.org/web/20150520175645/http://137.189.35.203/WebUI/CatDatabase/Data/CAT_DATASET_01.zip
# !unzip CAT_DATASET_01.zip
# !wget https://web.archive.org/web/20150520175645/http://137.189.35.203/WebUI/CatDatabase/Data/CAT_DATASET_02.zip
# !unzip CAT_DATASET_02.zip
# !wget https://web.archive.org/web/20150520175645/http://137.189.35.203/WebUI/CatDatabase/Data/00000003_015.jpg.cat
# !mv 00000003_015.jpg.cat "./CAT_00"
# !mv CAT_* "/content/drive/MyDrive/AdvancedComputerVision/BBR/images"

# %%
# %cd "/content/drive/MyDrive/CAT DATABASE"
# Out:
# /content/drive/MyDrive/CAT DATABASE

# %%
# !ls .
# Out:
#  00000003_015.jpg.cat   CAT_DATASET_02	   dataset.py	 Untitled0.ipynb
#  CAT_DATASET_01        'Colab Notebooks'   __pycache__

# %%
import sys
import os
CURRENT_DIR = os.getcwd()
sys.path.append(CURRENT_DIR)

# %%
import sys
from dataset import Dataset
import numpy as np
import argparse
import random
from scipy import misc
from skimage import draw
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint

np.random.seed(42)
random.seed(42)

# %%
MODEL_IMAGE_HEIGHT = 128
MODEL_IMAGE_WIDTH = 128
NB_LOAD_IMAGES = 9500
SPLIT = 0.1 # Tỉ lệ giữa train và validation là 9 : 1
EPOCHS = 150
BATCH_SIZE = 64
SAVE_WEIGHTS_FILEPATH = os.path.join(CURRENT_DIR, "cat_face_locator.weights")
SAVE_WEIGHTS_CHECKPOINT_FILEPATH = os.path.join(CURRENT_DIR, "cat_face_locator.best.weights")
SAVE_PREDICTIONS = True
SAVE_PREDICTIONS_DIR = os.path.join(CURRENT_DIR, "predictions")
DATASET_DIR = os.getcwd()

# %%
subdir_names = []

for i in (1, 2):
  cat_dataset = f'CAT_DATASET_0{i}'
  for subdir in os.listdir(os.path.join(os.getcwd(), cat_dataset)):
    subdir_names.append(os.path.join(cat_dataset, subdir))

dataset = Dataset(subdir_names)

# %%
def load_xy(dataset, nb_load):
    """Loads X and y (examples with labels) for the dataset.
    Examples are images.
    Labels are the coordinates of the face rectangles with their half-heights and half-widths
    (each normalized to 0-1 with respect to the image dimensions.)

    Args:
        dataset            The Dataset object.
        nb_load            Intended number of images to load.
    Returns:
        X (numpy array of shape (N, height, width, 3)),
        y (numpy array of shape (N, 4))
    """
    i = 0
    nb_images = min(nb_load, len(dataset.fps))
    X = np.zeros((nb_images, MODEL_IMAGE_HEIGHT, MODEL_IMAGE_WIDTH, 3), dtype=np.float32)
    y = np.zeros((nb_images, 4), dtype=np.float32)

    for img_idx, image in enumerate(dataset.get_images()):
        if img_idx % 100 == 0:
            print("Loading image %d of %d..." % (img_idx+1, nb_images))
        image.resize(MODEL_IMAGE_HEIGHT, MODEL_IMAGE_WIDTH)
        # Norm image
        X[i] = image.to_array() / 255.0
        # Prepare groundtruth
        face_rect = image.keypoints.get_rectangle(image)
        face_rect.normalize(image)
        center = face_rect.get_center()
        width = face_rect.get_width() / 2
        height = face_rect.get_height() / 2
        y[i] = [center.y, center.x, height, width]
        
        i += 1
        if i >= nb_images:
            break

    return X, y

def unnormalize_prediction(y, x, half_height, half_width, \
                           img_height=MODEL_IMAGE_HEIGHT, img_width=MODEL_IMAGE_WIDTH):
    """Transforms a predictions from normalized (0 to 1) y, x, half-width,
    half-height to pixel values (top left y, top left x, bottom right y,
    bottom right x).
    Args:
        y: Normalized y coordinate of rectangle center.
        x: Normalized x coordinate of rectangle center.
        half_height: Normalized height of rectangle.
        half_width: Normalized width of rectangle.
        img_height: Height of the image to use while unnormalizing.
        img_width: Width of the image to use while unnormalizing.
    Returns:
        (top left y in px, top left x in px, bottom right y in px,
        bottom right x in px)
    """
    # calculate x, y of corners in pixels
    tl_y = int((y - half_height) * img_height)
    tl_x = int((x - half_width) * img_width)
    br_y = int((y + half_height) * img_height)
    br_x = int((x + half_width) * img_width)

    # make sure that x and y coordinates are within image boundaries
    tl_y = clip(0, tl_y, img_height-2)
    tl_x = clip(0, tl_x, img_width-2)
    br_y = clip(0, br_y, img_height-1)
    br_x = clip(0, br_x, img_width-1)

    # make sure that top left corner is really top left of bottom right values
    if tl_y > br_y:
        tl_y, br_y = br_y, tl_y
    if tl_x > br_x:
        tl_x, br_x = br_x, tl_x

    # make sure that the area covered is at least 1px,
    # move preferably the top left corner
    # but dont move it outside of the image
    if tl_y == br_y:
        if tl_y == 0:
            br_y += 1
        else:
            tl_y -= 1

    if tl_x == br_x:
        if tl_x == 0:
            br_x += 1
        else:
            tl_x -= 1

    return tl_y, tl_x, br_y, br_x

def draw_predicted_rectangle(image_arr, y, x, half_height, half_width):
    """Draws a rectangle onto the image at the provided coordinates.
    Args:
        image_arr: Numpy array of the image.
        y: y-coordinate of the rectangle (normalized to 0-1).
        x: x-coordinate of the rectangle (normalized to 0-1).
        half_height: Half of the height of the rectangle (normalized to 0-1).
        half_width: Half of the width of the rectangle (normalized to 0-1).
    Returns:
        Modified image (numpy array)
    """
    #assert image_arr.shape[0] == 3, str(image_arr.shape)
    #height = image_arr.shape[1]
    #width = image_arr.shape[2]
    height = image_arr.shape[0]
    width = image_arr.shape[1]
    tl_y, tl_x, br_y, br_x = unnormalize_prediction(y, x, half_height, half_width, \
                                                    img_height=height, img_width=width)
    image_arr = np.copy(image_arr) * 255
    #image_arr = np.rollaxis(image_arr, 0, 3)
    return draw_rectangle(image_arr, tl_y, tl_x, br_y, br_x)

def draw_rectangle(img, tl_y, tl_x, br_y, br_x):
    """Draws a rectangle onto an image.
    Args:
        img: The image as a numpy array of shape (row, col, channel).
        tl_y: Top left y coordinate as pixel.
        tl_x: Top left x coordinate as pixel.
        br_y: Top left y coordinate as pixel.
        br_x: Top left x coordinate as pixel.
    Returns:
        image with rectangle
    """
    assert img.shape[2] == 3, img.shape[2]
    img = np.copy(img)
    lines = [
        (tl_y, tl_x, tl_y, br_x), # top left to top right
        (tl_y, br_x, br_y, br_x), # top right to bottom right
        (br_y, br_x, br_y, tl_x), # bottom right to bottom left
        (br_y, tl_x, tl_y, tl_x)  # bottom left to top left
    ]
    for y0, x0, y1, x1 in lines:
        rr, cc, val = draw.line_aa(y0, x0, y1, x1)
        img[rr, cc, 0] = val * 255

    return img

def clip(lower, val, upper):
    """Clips a value. For lower bound L, upper bound U and value V it
    makes sure that L <= V <= U holds.
    Args:
        lower: Lower boundary (including)
        val: The value to clip
        upper: Upper boundary (including)
    Returns:
        value within bounds
    """
    if val < lower:
        return lower
    elif val > upper:
        return upper
    else:
        return val

# %%
from keras.applications import VGG16

def create_model(image_height, image_width, loss, optimizer):
    """Creates the cat face locator model.

    Args:
        image_height: The height of the input images.
        image_width: The width of the input images.
        loss: Keras loss function (name or object), e.g. "mse".
        optimizer: Keras optimizer to use, e.g. Adam() or "sgd".
    Returns:
        Sequential
    """

    # Load VGG16 model pretrained on ImageNet dataset excluding fully connected layers (Classification Head) (include_top = False)
    vgg_conv = VGG16(weights='imagenet', include_top=False, input_shape=(image_height, image_width, 3))

    # Freeze the layers except the last 4 layers
    # CODE: for each layer in vgg_conv.layer --> set 'trainable' = False
    for layer in vgg_conv.layers:
      layer.trainable = False


    # Create the model
    model = Sequential()
    # CODE: Add vgg_conv to the model
    # ....
    model.add(vgg_conv)
    # After adding vgg_conv, the last tensor should be flatten to be a vector
    model.add(Flatten())

    # CODE: Add bounding box Regression Head here.
    # Please choose number of neuron in each layer and suitable activation functions
    # You may use Dropout for generalization
    # Adding 3 layers, 4096 neurons -> ReLU-> 4096 neurons -> ReLU 4 neurons
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4))

    





    # Compile with mean squared error
    print("Compiling...")
    model.compile(loss=loss, optimizer=optimizer)

    return model

# %%
# load images and labels
print("Loading images...")
X, y = load_xy(dataset, NB_LOAD_IMAGES)

# split train and val
nb_images = X.shape[0]
nb_train = int(nb_images * (1 - SPLIT))
X_train = X[0:nb_train, ...]
y_train = y[0:nb_train, ...]
X_val = X[nb_train:, ...]
y_val = y[nb_train:, ...]
# Out:
# Loading images...
# Loading image 1 of 9500...
# Loading image 101 of 9500...
# Loading image 201 of 9500...
# Loading image 301 of 9500...
# Loading image 401 of 9500...
# Loading image 501 of 9500...
# Loading image 601 of 9500...
# Loading image 701 of 9500...
# Loading image 801 of 9500...
# Loading image 901 of 9500...
# Loading image 1001 of 9500...
# Loading image 1101 of 9500...
# Loading image 1201 of 9500...
# Loading image 1301 of 9500...
# Loading image 1401 of 9500...
# Loading image 1501 of 9500...
# Loading image 1601 of 9500...
# Loading image 1701 of 9500...
# Loading image 1801 of 9500...
# Loading image 1901 of 9500...
# Loading image 2001 of 9500...
# Loading image 2101 of 9500...
# Loading image 2201 of 9500...
# Loading image 2301 of 9500...
# Loading image 2401 of 9500...
# Loading image 2501 of 9500...
# Loading image 2601 of 9500...
# Loading image 2701 of 9500...
# Loading image 2801 of 9500...
# Loading image 2901 of 9500...
# Loading image 3001 of 9500...
# Loading image 3101 of 9500...
# Loading image 3201 of 9500...
# Loading image 3301 of 9500...
# Loading image 3401 of 9500...
# Loading image 3501 of 9500...
# Loading image 3601 of 9500...
# Loading image 3701 of 9500...
# Loading image 3801 of 9500...
# Loading image 3901 of 9500...
# Loading image 4001 of 9500...
# Loading image 4101 of 9500...
# Loading image 4201 of 9500...
# Loading image 4301 of 9500...
# Loading image 4401 of 9500...
# Loading image 4501 of 9500...
# Loading image 4601 of 9500...
# Loading image 4701 of 9500...
# Loading image 4801 of 9500...
# Loading image 4901 of 9500...
# Loading image 5001 of 9500...
# Loading image 5101 of 9500...
# Loading image 5201 of 9500...
# Loading image 5301 of 9500...
# Loading image 5401 of 9500...
# Loading image 5501 of 9500...
# Loading image 5601 of 9500...
# Loading image 5701 of 9500...
# Loading image 5801 of 9500...
# Loading image 5901 of 9500...
# Loading image 6001 of 9500...
# Loading image 6101 of 9500...
# Loading image 6201 of 9500...
# Loading image 6301 of 9500...
# Loading image 6401 of 9500...
# Loading image 6501 of 9500...
# Loading image 6601 of 9500...
# Loading image 6701 of 9500...
# Loading image 6801 of 9500...
# Loading image 6901 of 9500...
# Loading image 7001 of 9500...
# Loading image 7101 of 9500...
# Loading image 7201 of 9500...
# Loading image 7301 of 9500...
# Loading image 7401 of 9500...
# Loading image 7501 of 9500...
# Loading image 7601 of 9500...
# Loading image 7701 of 9500...
# Loading image 7801 of 9500...
# Loading image 7901 of 9500...
# Loading image 8001 of 9500...
# Loading image 8101 of 9500...
# Loading image 8201 of 9500...
# Loading image 8301 of 9500...
# Loading image 8401 of 9500...
# Loading image 8501 of 9500...
# Loading image 8601 of 9500...
# Loading image 8701 of 9500...
# Loading image 8801 of 9500...
# Loading image 8901 of 9500...
# Loading image 9001 of 9500...
# Loading image 9101 of 9500...
# Loading image 9201 of 9500...
# Loading image 9301 of 9500...
# Loading image 9401 of 9500...

# %%
# STEP 2: create model with Regression Head only, remove Classification Head
# You can change loss and optimizer if you want
print("Creating model...")
model = create_model(MODEL_IMAGE_HEIGHT, MODEL_IMAGE_WIDTH, "mse", Adam())
# Out:
# Creating model...
# Compiling...

# %%
import cv2

#  STEP 3: Train with Regression Head
# Fit data to model
checkpoint_cb = ModelCheckpoint(SAVE_WEIGHTS_CHECKPOINT_FILEPATH, verbose=1, \
                                save_best_only=True)
model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=0.0,
          validation_data=(X_val, y_val),
          callbacks=[checkpoint_cb])

# save weights
print("Saving weights...")
model.save_weights(SAVE_WEIGHTS_FILEPATH, overwrite=True)

#model.load_weights(SAVE_WEIGHTS_CHECKPOINT_FILEPATH)

# save predictions on val set
if SAVE_PREDICTIONS:
    print("Saving example predictions...")
    y_preds = model.predict(X_val, batch_size=BATCH_SIZE)
    for img_idx, (y, x, half_height, half_width) in enumerate(y_preds):
        img_arr = draw_predicted_rectangle(X_val[img_idx], y, x, half_height, half_width)
        filepath = os.path.join(SAVE_PREDICTIONS_DIR, "%d.png" % (img_idx,))
        cv2.imwrite(filepath, np.squeeze(img_arr))
# Out:
# Epoch 1/150
# 134/134 [==============================] - 56s 145ms/step - loss: 81.9233 - val_loss: 0.0078
#
# Epoch 00001: val_loss improved from inf to 0.00782, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 2/150
# 134/134 [==============================] - 13s 98ms/step - loss: 0.0067 - val_loss: 0.0044
#
# Epoch 00002: val_loss improved from 0.00782 to 0.00440, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 3/150
# 134/134 [==============================] - 13s 100ms/step - loss: 0.0059 - val_loss: 0.0048
#
# Epoch 00003: val_loss did not improve from 0.00440
# Epoch 4/150
# 134/134 [==============================] - 13s 101ms/step - loss: 0.0052 - val_loss: 0.0049
#
# Epoch 00004: val_loss did not improve from 0.00440
# Epoch 5/150
# 134/134 [==============================] - 14s 102ms/step - loss: 0.0041 - val_loss: 0.0037
#
# Epoch 00005: val_loss improved from 0.00440 to 0.00373, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 6/150
# 134/134 [==============================] - 14s 105ms/step - loss: 0.0033 - val_loss: 0.0041
#
# Epoch 00006: val_loss did not improve from 0.00373
# Epoch 7/150
# 134/134 [==============================] - 14s 106ms/step - loss: 0.0031 - val_loss: 0.0040
#
# Epoch 00007: val_loss did not improve from 0.00373
# Epoch 8/150
# 134/134 [==============================] - 14s 106ms/step - loss: 0.0025 - val_loss: 0.0056
#
# Epoch 00008: val_loss did not improve from 0.00373
# Epoch 9/150
# 134/134 [==============================] - 14s 104ms/step - loss: 0.0028 - val_loss: 0.0054
#
# Epoch 00009: val_loss did not improve from 0.00373
# Epoch 10/150
# 134/134 [==============================] - 14s 103ms/step - loss: 0.0022 - val_loss: 0.0051
#
# Epoch 00010: val_loss did not improve from 0.00373
# Epoch 11/150
# 134/134 [==============================] - 14s 103ms/step - loss: 0.0018 - val_loss: 0.0044
#
# Epoch 00011: val_loss did not improve from 0.00373
# Epoch 12/150
# 134/134 [==============================] - 14s 104ms/step - loss: 0.0017 - val_loss: 0.0040
#
# Epoch 00012: val_loss did not improve from 0.00373
# Epoch 13/150
# 134/134 [==============================] - 14s 105ms/step - loss: 0.0015 - val_loss: 0.0039
#
# Epoch 00013: val_loss did not improve from 0.00373
# Epoch 14/150
# 134/134 [==============================] - 14s 105ms/step - loss: 0.0012 - val_loss: 0.0044
#
# Epoch 00014: val_loss did not improve from 0.00373
# Epoch 15/150
# 134/134 [==============================] - 14s 104ms/step - loss: 0.0012 - val_loss: 0.0041
#
# Epoch 00015: val_loss did not improve from 0.00373
# Epoch 16/150
# 134/134 [==============================] - 14s 104ms/step - loss: 9.5279e-04 - val_loss: 0.0042
#
# Epoch 00016: val_loss did not improve from 0.00373
# Epoch 17/150
# 134/134 [==============================] - 14s 104ms/step - loss: 0.0011 - val_loss: 0.0040
#
# Epoch 00017: val_loss did not improve from 0.00373
# Epoch 18/150
# 134/134 [==============================] - 14s 104ms/step - loss: 8.7553e-04 - val_loss: 0.0040
#
# Epoch 00018: val_loss did not improve from 0.00373
# Epoch 19/150
# 134/134 [==============================] - 14s 105ms/step - loss: 7.2427e-04 - val_loss: 0.0040
#
# Epoch 00019: val_loss did not improve from 0.00373
# Epoch 20/150
# 134/134 [==============================] - 14s 105ms/step - loss: 7.1466e-04 - val_loss: 0.0041
#
# Epoch 00020: val_loss did not improve from 0.00373
# Epoch 21/150
# 134/134 [==============================] - 14s 105ms/step - loss: 6.8051e-04 - val_loss: 0.0042
#
# Epoch 00021: val_loss did not improve from 0.00373
# Epoch 22/150
# 134/134 [==============================] - 14s 105ms/step - loss: 5.9413e-04 - val_loss: 0.0042
#
# Epoch 00022: val_loss did not improve from 0.00373
# Epoch 23/150
# 134/134 [==============================] - 14s 105ms/step - loss: 6.7248e-04 - val_loss: 0.0043
#
# Epoch 00023: val_loss did not improve from 0.00373
# Epoch 24/150
# 134/134 [==============================] - 14s 105ms/step - loss: 5.8755e-04 - val_loss: 0.0041
#
# Epoch 00024: val_loss did not improve from 0.00373
# Epoch 25/150
# 134/134 [==============================] - 14s 105ms/step - loss: 4.7694e-04 - val_loss: 0.0042
#
# Epoch 00025: val_loss did not improve from 0.00373
# Epoch 26/150
# 134/134 [==============================] - 14s 105ms/step - loss: 5.1487e-04 - val_loss: 0.0041
#
# Epoch 00026: val_loss did not improve from 0.00373
# Epoch 27/150
# 134/134 [==============================] - 14s 105ms/step - loss: 4.9757e-04 - val_loss: 0.0042
#
# Epoch 00027: val_loss did not improve from 0.00373
# Epoch 28/150
# 134/134 [==============================] - 14s 105ms/step - loss: 5.2488e-04 - val_loss: 0.0040
#
# Epoch 00028: val_loss did not improve from 0.00373
# Epoch 29/150
# 134/134 [==============================] - 14s 105ms/step - loss: 4.4636e-04 - val_loss: 0.0055
#
# Epoch 00029: val_loss did not improve from 0.00373
# Epoch 30/150
# 134/134 [==============================] - 14s 105ms/step - loss: 5.8446e-04 - val_loss: 0.0042
#
# Epoch 00030: val_loss did not improve from 0.00373
# Epoch 31/150
# 134/134 [==============================] - 14s 105ms/step - loss: 4.4009e-04 - val_loss: 0.0040
#
# Epoch 00031: val_loss did not improve from 0.00373
# Epoch 32/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.0845e-04 - val_loss: 0.0043
#
# Epoch 00032: val_loss did not improve from 0.00373
# Epoch 33/150
# 134/134 [==============================] - 14s 104ms/step - loss: 3.0043e-04 - val_loss: 0.0042
#
# Epoch 00033: val_loss did not improve from 0.00373
# Epoch 34/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.9812e-04 - val_loss: 0.0042
#
# Epoch 00034: val_loss did not improve from 0.00373
# Epoch 35/150
# 134/134 [==============================] - 14s 104ms/step - loss: 3.1068e-04 - val_loss: 0.0043
#
# Epoch 00035: val_loss did not improve from 0.00373
# Epoch 36/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.2690e-04 - val_loss: 0.0041
#
# Epoch 00036: val_loss did not improve from 0.00373
# Epoch 37/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.2725e-04 - val_loss: 0.0042
#
# Epoch 00037: val_loss did not improve from 0.00373
# Epoch 38/150
# 134/134 [==============================] - 14s 104ms/step - loss: 3.5758e-04 - val_loss: 0.0040
#
# Epoch 00038: val_loss did not improve from 0.00373
# Epoch 39/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.0883e-04 - val_loss: 0.0041
#
# Epoch 00039: val_loss did not improve from 0.00373
# Epoch 40/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.1117e-04 - val_loss: 0.0040
#
# Epoch 00040: val_loss did not improve from 0.00373
# Epoch 41/150
# 134/134 [==============================] - 14s 104ms/step - loss: 3.5469e-04 - val_loss: 0.0042
#
# Epoch 00041: val_loss did not improve from 0.00373
# Epoch 42/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.7999e-04 - val_loss: 0.0041
#
# Epoch 00042: val_loss did not improve from 0.00373
# Epoch 43/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2471e-04 - val_loss: 0.0040
#
# Epoch 00043: val_loss did not improve from 0.00373
# Epoch 44/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2086e-04 - val_loss: 0.0040
#
# Epoch 00044: val_loss did not improve from 0.00373
# Epoch 45/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.0272e-04 - val_loss: 0.0040
#
# Epoch 00045: val_loss did not improve from 0.00373
# Epoch 46/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.7910e-04 - val_loss: 0.0040
#
# Epoch 00046: val_loss did not improve from 0.00373
# Epoch 47/150
# 134/134 [==============================] - 14s 104ms/step - loss: 3.1004e-04 - val_loss: 0.0042
#
# Epoch 00047: val_loss did not improve from 0.00373
# Epoch 48/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.4324e-04 - val_loss: 0.0042
#
# Epoch 00048: val_loss did not improve from 0.00373
# Epoch 49/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.0764e-04 - val_loss: 0.0039
#
# Epoch 00049: val_loss did not improve from 0.00373
# Epoch 50/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.5748e-04 - val_loss: 0.0039
#
# Epoch 00050: val_loss did not improve from 0.00373
# Epoch 51/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.6080e-04 - val_loss: 0.0039
#
# Epoch 00051: val_loss did not improve from 0.00373
# Epoch 52/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.9900e-04 - val_loss: 0.0039
#
# Epoch 00052: val_loss did not improve from 0.00373
# Epoch 53/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.9552e-04 - val_loss: 0.0040
#
# Epoch 00053: val_loss did not improve from 0.00373
# Epoch 54/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.0148e-04 - val_loss: 0.0039
#
# Epoch 00054: val_loss did not improve from 0.00373
# Epoch 55/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.3210e-04 - val_loss: 0.0038
#
# Epoch 00055: val_loss did not improve from 0.00373
# Epoch 56/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2361e-04 - val_loss: 0.0041
#
# Epoch 00056: val_loss did not improve from 0.00373
# Epoch 57/150
# 134/134 [==============================] - 14s 104ms/step - loss: 2.9243e-04 - val_loss: 0.0040
#
# Epoch 00057: val_loss did not improve from 0.00373
# Epoch 58/150
# 134/134 [==============================] - 14s 104ms/step - loss: 3.5080e-04 - val_loss: 0.0039
#
# Epoch 00058: val_loss did not improve from 0.00373
# Epoch 59/150
# 134/134 [==============================] - 14s 105ms/step - loss: 3.5740e-04 - val_loss: 0.0040
#
# Epoch 00059: val_loss did not improve from 0.00373
# Epoch 60/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.7067e-04 - val_loss: 0.0039
#
# Epoch 00060: val_loss did not improve from 0.00373
# Epoch 61/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.5580e-04 - val_loss: 0.0038
#
# Epoch 00061: val_loss did not improve from 0.00373
# Epoch 62/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.1086e-04 - val_loss: 0.0039
#
# Epoch 00062: val_loss did not improve from 0.00373
# Epoch 63/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.5285e-04 - val_loss: 0.0039
#
# Epoch 00063: val_loss did not improve from 0.00373
# Epoch 64/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.8094e-04 - val_loss: 0.0038
#
# Epoch 00064: val_loss did not improve from 0.00373
# Epoch 65/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2706e-04 - val_loss: 0.0038
#
# Epoch 00065: val_loss did not improve from 0.00373
# Epoch 66/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.4831e-04 - val_loss: 0.0038
#
# Epoch 00066: val_loss did not improve from 0.00373
# Epoch 67/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2424e-04 - val_loss: 0.0039
#
# Epoch 00067: val_loss did not improve from 0.00373
# Epoch 68/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.8723e-04 - val_loss: 0.0039
#
# Epoch 00068: val_loss did not improve from 0.00373
# Epoch 69/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.9309e-04 - val_loss: 0.0039
#
# Epoch 00069: val_loss did not improve from 0.00373
# Epoch 70/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.9304e-04 - val_loss: 0.0038
#
# Epoch 00070: val_loss did not improve from 0.00373
# Epoch 71/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.4706e-04 - val_loss: 0.0038
#
# Epoch 00071: val_loss did not improve from 0.00373
# Epoch 72/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.9405e-04 - val_loss: 0.0037
#
# Epoch 00072: val_loss improved from 0.00373 to 0.00365, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 73/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.3711e-04 - val_loss: 0.0038
#
# Epoch 00073: val_loss did not improve from 0.00365
# Epoch 74/150
# 134/134 [==============================] - 14s 106ms/step - loss: 2.1021e-04 - val_loss: 0.0038
#
# Epoch 00074: val_loss did not improve from 0.00365
# Epoch 75/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.8347e-04 - val_loss: 0.0038
#
# Epoch 00075: val_loss did not improve from 0.00365
# Epoch 76/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.6353e-04 - val_loss: 0.0037
#
# Epoch 00076: val_loss did not improve from 0.00365
# Epoch 77/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.5402e-04 - val_loss: 0.0038
#
# Epoch 00077: val_loss did not improve from 0.00365
# Epoch 78/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.2985e-04 - val_loss: 0.0037
#
# Epoch 00078: val_loss did not improve from 0.00365
# Epoch 79/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.6559e-04 - val_loss: 0.0037
#
# Epoch 00079: val_loss did not improve from 0.00365
# Epoch 80/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.6744e-04 - val_loss: 0.0037
#
# Epoch 00080: val_loss did not improve from 0.00365
# Epoch 81/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.5582e-04 - val_loss: 0.0038
#
# Epoch 00081: val_loss did not improve from 0.00365
# Epoch 82/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.0070e-04 - val_loss: 0.0038
#
# Epoch 00082: val_loss did not improve from 0.00365
# Epoch 83/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.3425e-04 - val_loss: 0.0039
#
# Epoch 00083: val_loss did not improve from 0.00365
# Epoch 84/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2466e-04 - val_loss: 0.0039
#
# Epoch 00084: val_loss did not improve from 0.00365
# Epoch 85/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.4498e-04 - val_loss: 0.0038
#
# Epoch 00085: val_loss did not improve from 0.00365
# Epoch 86/150
# 134/134 [==============================] - 14s 104ms/step - loss: 2.1121e-04 - val_loss: 0.0036
#
# Epoch 00086: val_loss improved from 0.00365 to 0.00364, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 87/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.0620e-04 - val_loss: 0.0037
#
# Epoch 00087: val_loss did not improve from 0.00364
# Epoch 88/150
# 134/134 [==============================] - 14s 106ms/step - loss: 2.1503e-04 - val_loss: 0.0039
#
# Epoch 00088: val_loss did not improve from 0.00364
# Epoch 89/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.8430e-04 - val_loss: 0.0038
#
# Epoch 00089: val_loss did not improve from 0.00364
# Epoch 90/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.7484e-04 - val_loss: 0.0038
#
# Epoch 00090: val_loss did not improve from 0.00364
# Epoch 91/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.5570e-04 - val_loss: 0.0037
#
# Epoch 00091: val_loss did not improve from 0.00364
# Epoch 92/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.5157e-04 - val_loss: 0.0037
#
# Epoch 00092: val_loss did not improve from 0.00364
# Epoch 93/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.3912e-04 - val_loss: 0.0037
#
# Epoch 00093: val_loss did not improve from 0.00364
# Epoch 94/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2104e-04 - val_loss: 0.0038
#
# Epoch 00094: val_loss did not improve from 0.00364
# Epoch 95/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.3054e-04 - val_loss: 0.0037
#
# Epoch 00095: val_loss did not improve from 0.00364
# Epoch 96/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2107e-04 - val_loss: 0.0037
#
# Epoch 00096: val_loss did not improve from 0.00364
# Epoch 97/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.3706e-04 - val_loss: 0.0038
#
# Epoch 00097: val_loss did not improve from 0.00364
# Epoch 98/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.8531e-04 - val_loss: 0.0037
#
# Epoch 00098: val_loss did not improve from 0.00364
# Epoch 99/150
# 134/134 [==============================] - 14s 105ms/step - loss: 2.2022e-04 - val_loss: 0.0036
#
# Epoch 00099: val_loss did not improve from 0.00364
# Epoch 100/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.5732e-04 - val_loss: 0.0036
#
# Epoch 00100: val_loss improved from 0.00364 to 0.00363, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 101/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.9015e-04 - val_loss: 0.0037
#
# Epoch 00101: val_loss did not improve from 0.00363
# Epoch 102/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.8218e-04 - val_loss: 0.0037
#
# Epoch 00102: val_loss did not improve from 0.00363
# Epoch 103/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.3878e-04 - val_loss: 0.0037
#
# Epoch 00103: val_loss did not improve from 0.00363
# Epoch 104/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.3735e-04 - val_loss: 0.0036
#
# Epoch 00104: val_loss did not improve from 0.00363
# Epoch 105/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.3641e-04 - val_loss: 0.0038
#
# Epoch 00105: val_loss did not improve from 0.00363
# Epoch 106/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.1927e-04 - val_loss: 0.0036
#
# Epoch 00106: val_loss did not improve from 0.00363
# Epoch 107/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.0790e-04 - val_loss: 0.0036
#
# Epoch 00107: val_loss did not improve from 0.00363
# Epoch 108/150
# 134/134 [==============================] - 14s 105ms/step - loss: 9.9792e-05 - val_loss: 0.0037
#
# Epoch 00108: val_loss did not improve from 0.00363
# Epoch 109/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2767e-04 - val_loss: 0.0037
#
# Epoch 00109: val_loss did not improve from 0.00363
# Epoch 110/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2179e-04 - val_loss: 0.0036
#
# Epoch 00110: val_loss improved from 0.00363 to 0.00363, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 111/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2540e-04 - val_loss: 0.0037
#
# Epoch 00111: val_loss did not improve from 0.00363
# Epoch 112/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.2279e-04 - val_loss: 0.0036
#
# Epoch 00112: val_loss improved from 0.00363 to 0.00361, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 113/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.3957e-04 - val_loss: 0.0037
#
# Epoch 00113: val_loss did not improve from 0.00361
# Epoch 114/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.3891e-04 - val_loss: 0.0036
#
# Epoch 00114: val_loss did not improve from 0.00361
# Epoch 115/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2824e-04 - val_loss: 0.0036
#
# Epoch 00115: val_loss improved from 0.00361 to 0.00358, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 116/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.4669e-04 - val_loss: 0.0036
#
# Epoch 00116: val_loss did not improve from 0.00358
# Epoch 117/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.1370e-04 - val_loss: 0.0036
#
# Epoch 00117: val_loss did not improve from 0.00358
# Epoch 118/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.4866e-04 - val_loss: 0.0036
#
# Epoch 00118: val_loss improved from 0.00358 to 0.00358, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 119/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.3377e-04 - val_loss: 0.0036
#
# Epoch 00119: val_loss improved from 0.00358 to 0.00356, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 120/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.0493e-04 - val_loss: 0.0036
#
# Epoch 00120: val_loss did not improve from 0.00356
# Epoch 121/150
# 134/134 [==============================] - 14s 107ms/step - loss: 8.8875e-05 - val_loss: 0.0036
#
# Epoch 00121: val_loss did not improve from 0.00356
# Epoch 122/150
# 134/134 [==============================] - 14s 106ms/step - loss: 9.6944e-05 - val_loss: 0.0036
#
# Epoch 00122: val_loss did not improve from 0.00356
# Epoch 123/150
# 134/134 [==============================] - 14s 104ms/step - loss: 9.8021e-05 - val_loss: 0.0036
#
# Epoch 00123: val_loss did not improve from 0.00356
# Epoch 124/150
# 134/134 [==============================] - 14s 104ms/step - loss: 7.9226e-05 - val_loss: 0.0036
#
# Epoch 00124: val_loss improved from 0.00356 to 0.00356, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 125/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2742e-04 - val_loss: 0.0035
#
# Epoch 00125: val_loss improved from 0.00356 to 0.00353, saving model to /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights
# INFO:tensorflow:Assets written to: /content/drive/My Drive/CAT DATABASE/cat_face_locator.best.weights/assets
# Epoch 126/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.0330e-04 - val_loss: 0.0036
#
# Epoch 00126: val_loss did not improve from 0.00353
# Epoch 127/150
# 134/134 [==============================] - 14s 107ms/step - loss: 9.1417e-05 - val_loss: 0.0036
#
# Epoch 00127: val_loss did not improve from 0.00353
# Epoch 128/150
# 134/134 [==============================] - 14s 106ms/step - loss: 1.2705e-04 - val_loss: 0.0036
#
# Epoch 00128: val_loss did not improve from 0.00353
# Epoch 129/150
# 134/134 [==============================] - 14s 104ms/step - loss: 9.7679e-05 - val_loss: 0.0036
#
# Epoch 00129: val_loss did not improve from 0.00353
# Epoch 130/150
# 134/134 [==============================] - 14s 104ms/step - loss: 1.1096e-04 - val_loss: 0.0036
#
# Epoch 00130: val_loss did not improve from 0.00353
# Epoch 131/150
# 134/134 [==============================] - 14s 104ms/step - loss: 8.0974e-05 - val_loss: 0.0036
#
# Epoch 00131: val_loss did not improve from 0.00353
# Epoch 132/150
# 134/134 [==============================] - 14s 105ms/step - loss: 7.1140e-05 - val_loss: 0.0036
#
# Epoch 00132: val_loss did not improve from 0.00353
# Epoch 133/150
# 134/134 [==============================] - 14s 105ms/step - loss: 6.6723e-05 - val_loss: 0.0036
#
# Epoch 00133: val_loss did not improve from 0.00353
# Epoch 134/150
# 134/134 [==============================] - 14s 105ms/step - loss: 9.1378e-05 - val_loss: 0.0035
#
# Epoch 00134: val_loss did not improve from 0.00353
# Epoch 135/150
# 134/134 [==============================] - 14s 105ms/step - loss: 8.3707e-05 - val_loss: 0.0037
#
# Epoch 00135: val_loss did not improve from 0.00353
# Epoch 136/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2905e-04 - val_loss: 0.0035
#
# Epoch 00136: val_loss did not improve from 0.00353
# Epoch 137/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.0826e-04 - val_loss: 0.0036
#
# Epoch 00137: val_loss did not improve from 0.00353
# Epoch 138/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2118e-04 - val_loss: 0.0036
#
# Epoch 00138: val_loss did not improve from 0.00353
# Epoch 139/150
# 134/134 [==============================] - 14s 105ms/step - loss: 9.5129e-05 - val_loss: 0.0035
#
# Epoch 00139: val_loss did not improve from 0.00353
# Epoch 140/150
# 134/134 [==============================] - 14s 105ms/step - loss: 7.5666e-05 - val_loss: 0.0037
#
# Epoch 00140: val_loss did not improve from 0.00353
# Epoch 141/150
# 134/134 [==============================] - 14s 105ms/step - loss: 6.4367e-05 - val_loss: 0.0035
#
# Epoch 00141: val_loss did not improve from 0.00353
# Epoch 142/150
# 134/134 [==============================] - 14s 105ms/step - loss: 5.2346e-05 - val_loss: 0.0036
#
# Epoch 00142: val_loss did not improve from 0.00353
# Epoch 143/150
# 134/134 [==============================] - 14s 105ms/step - loss: 6.2658e-05 - val_loss: 0.0036
#
# Epoch 00143: val_loss did not improve from 0.00353
# Epoch 144/150
# 134/134 [==============================] - 14s 105ms/step - loss: 7.6235e-05 - val_loss: 0.0037
#
# Epoch 00144: val_loss did not improve from 0.00353
# Epoch 145/150
# 134/134 [==============================] - 14s 105ms/step - loss: 8.7937e-05 - val_loss: 0.0037
#
# Epoch 00145: val_loss did not improve from 0.00353
# Epoch 146/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.1203e-04 - val_loss: 0.0035
#
# Epoch 00146: val_loss did not improve from 0.00353
# Epoch 147/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.2056e-04 - val_loss: 0.0036
#
# Epoch 00147: val_loss did not improve from 0.00353
# Epoch 148/150
# 134/134 [==============================] - 14s 105ms/step - loss: 1.0692e-04 - val_loss: 0.0036
#
# Epoch 00148: val_loss did not improve from 0.00353
# Epoch 149/150
# 134/134 [==============================] - 14s 105ms/step - loss: 7.9772e-05 - val_loss: 0.0036
#
# Epoch 00149: val_loss did not improve from 0.00353
# Epoch 150/150
# 134/134 [==============================] - 14s 105ms/step - loss: 6.7978e-05 - val_loss: 0.0036
#
# Epoch 00150: val_loss did not improve from 0.00353
# Saving weights...
# Saving example predictions...

# %%
# Step 4
# CODE: Apply Classification Head and Regression Head for a full system of localization

# %% [markdown]
# Hmm... Chỗ này chưa hiểu lắm, áp dụng classification mà dữ liệu chỉ toàn là mèo - phân biệt với cái gì, nhãn dữ liệu chưa có.
#
# Hơn nữa, để thiết mô hình có nhiều output thì cần sử dụng functional api, hàm create model lại sử dụng sequential api.
